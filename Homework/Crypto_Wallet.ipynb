# %%
import os
import requests
import json
import pandas as pd

# %%
# Set current amount of crypto assets
# YOUR CODE HERE!

my_btc = 1.2
my_eth = 5.3

# %%
# Crypto API URLs
btc_url = "https://api.alternative.me/v2/ticker/Bitcoin/?convert=CAD"
eth_url = "https://api.alternative.me/v2/ticker/Ethereum/?convert=CAD"

# %%
# Fetch current BTC price
# YOUR CODE HERE!

btc_data = requests.get(btc_url).json()
print(json.dumps(btc_data, indent=4))

# Fetch current ETH price
# YOUR CODE HERE!

eth_data = requests.get(eth_url).json()
print(json.dumps(eth_data, indent=4))

# Compute current value of my crpto
# YOUR CODE HERE!

btc_value = btc_data["data"]["1"]["quotes"]["USD"]["price"]
eth_value = eth_data["data"]["1027"]["quotes"]["USD"]["price"]

my_btc_value = btc_value * my_btc
my_eth_value = eth_value * my_eth

# Print current crypto wallet balance
print(f"The current value of your {my_btc} BTC is ${my_btc_value:0.2f}")
print(f"The current value of your {my_eth} ETH is ${my_eth_value:0.2f}")
# Out:
# {
#     "data": {
#         "1": {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "website_slug": "bitcoin",
#             "rank": 1,
#             "circulating_supply": 19151218,
#             "total_supply": 19151218,
#             "max_supply": 21000000,
#             "quotes": {
#                 "USD": {
#                     "price": 20164.0,
#                     "volume_24h": 38285234340,
#                     "market_cap": 385581398272,
#                     "percentage_change_1h": -0.148824169129696,
#                     "percentage_change_24h": -0.837758601082529,
#                     "percentage_change_7d": 4.58118195773429,
#                     "percent_change_1h": -0.148824169129696,
#                     "percent_change_24h": -0.837758601082529,
#                     "percent_change_7d": 4.58118195773429
#                 },
#                 "CAD": {
#                     "price": 26578.1684,
#                     "volume_24h": 50463767383.554,
#                     "market_cap": 508234841062.323,
#                     "percent_change_1h": -0.148824169129696,
#                     "percent_change_24h": -0.837758601082529,
#                     "percent_change_7d": 4.58118195773429
#                 }
#             },
#             "last_updated": 1663241355
#         }
#     },
#     "metadata": {
#         "timestamp": 1663241355,
#         "num_cryptocurrencies": 3116,
#         "error": null
#     }
# }
# {
#     "data": {
#         "1027": {
#             "id": 1027,
#             "name": "Ethereum",
#             "symbol": "ETH",
#             "website_slug": "ethereum",
#             "rank": 2,
#             "circulating_supply": 120523208,
#             "total_supply": 120523208,
#             "max_supply": 120522258,
#             "quotes": {
#                 "USD": {
#                     "price": 1586.44,
#                     "volume_24h": 24183692232,
#                     "market_cap": 190584539203,
#                     "percentage_change_1h": -0.422674936617525,
#                     "percentage_change_24h": -1.06296693896998,
#                     "percentage_change_7d": -2.66564259729745,
#                     "percent_change_1h": -0.422674936617525,
#                     "percent_change_24h": -1.06296693896998,
#                     "percent_change_7d": -2.66564259729745
#                 },
#                 "CAD": {
#                     "price": 2091.086564,
#                     "volume_24h": 31876524730.9992,
#                     "market_cap": 251209481123.474,
#                     "percent_change_1h": -0.422674936617525,
#                     "percent_change_24h": -1.06296693896998,
#                     "percent_change_7d": -2.66564259729745
#                 }
#             },
#             "last_updated": 1663241369
#         }
#     },
#     "metadata": {
#         "timestamp": 1663241369,
#         "num_cryptocurrencies": 3116,
#         "error": null
#     }
# }
# The current value of your 1.2 BTC is $24196.80
# The current value of your 5.3 ETH is $8408.13
